# %%
import pandas as pd

df= pd.read_csv('data.csv')

df.head()
# Out:
#          Country  AveragScore  SafetySecurity  PersonelFreedom  Governance  \
# 0        Denmark        84.55           92.59            94.09       89.45
# 1         Sweden        83.67           90.97            91.90       86.41
# 2         Norway        83.59           93.30            94.10       89.66
# 3        Finland        83.47           89.56            91.96       90.41
# 4    Switzerland        83.42           95.66            87.50       87.67
#
#    SocialCapital  InvestmentEnvironment  EnterpriseConditions  \
# 0          82.56                  82.42                 79.64
# 1          78.29                  82.81                 75.54
# 2          79.03                  82.24                 75.95
# 3          77.27                  84.12                 77.25
# 4          69.14                  80.81                 83.84
#
#    MarketAccessInfrastructure  EconomicQuality  LivingConditions  Health  \
# 0                       78.79            76.81             95.77   81.07
# 1                       79.67            76.18             95.33   82.28
# 2                       75.87            77.25             94.70   82.98
# 3                       78.77            70.28             94.46   81.19
# 4                       78.65            79.71             94.66   82.11
#
#    Education  NaturalEnvironment
# 0      87.48               73.94
# 1      85.92               78.74
# 2      85.68               72.37
# 3      88.38               77.99
# 4      87.72               73.60

# %%
df = df.select_dtypes(include=['int64','float64'])

# %%
df
# Out:
#      AveragScore  SafetySecurity  PersonelFreedom  Governance  SocialCapital  \
# 0          84.55           92.59            94.09       89.45          82.56
# 1          83.67           90.97            91.90       86.41          78.29
# 2          83.59           93.30            94.10       89.66          79.03
# 3          83.47           89.56            91.96       90.41          77.27
# 4          83.42           95.66            87.50       87.67          69.14
# ..           ...             ...              ...         ...            ...
# 162        34.39           31.91            34.32       23.80          43.50
# 163        34.18           20.93            31.02       29.47          31.17
# 164        32.83           35.30            36.83       28.40          36.72
# 165        32.65           22.60            25.30       18.20          38.44
# 166        30.40           16.54            26.98       22.16          36.10
#
#      InvestmentEnvironment  EnterpriseConditions  MarketAccessInfrastructure  \
# 0                    82.42                 79.64                       78.79
# 1                    82.81                 75.54                       79.67
# 2                    82.24                 75.95                       75.87
# 3                    84.12                 77.25                       78.77
# 4                    80.81                 83.84                       78.65
# ..                     ...                   ...                         ...
# 162                  31.16                 41.79                       26.75
# 163                  30.25                 42.01                       29.67
# 164                  26.32                 40.21                       25.49
# 165                  22.76                 33.12                       30.93
# 166                  33.34                 37.52                       32.89
#
#      EconomicQuality  LivingConditions  Health  Education  NaturalEnvironment
# 0              76.81             95.77   81.07      87.48               73.94
# 1              76.18             95.33   82.28      85.92               78.74
# 2              77.25             94.70   82.98      85.68               72.37
# 3              70.28             94.46   81.19      88.38               77.99
# 4              79.71             94.66   82.11      87.72               73.60
# ..               ...               ...     ...        ...                 ...
# 162            28.23             32.07   44.38      26.32               48.46
# 163            33.75             39.74   50.91      27.11               44.11
# 164            40.34             19.21   31.95      18.62               54.57
# 165            28.81             41.58   57.45      28.12               44.49
# 166            32.30             21.99   35.69      18.99               50.35
#
# [167 rows x 13 columns]

# %%
#shapiro test
from scipy.stats import shapiro

for col in df.columns:
    stat, p = shapiro(df[col])
    alpha = 0.05
    if p > alpha:
        print(col,'looks Gaussian (fail to reject H0)')
        df.drop(col, axis=1, inplace=True)
# Out:
# SocialCapital looks Gaussian (fail to reject H0)
# NaturalEnvironment looks Gaussian (fail to reject H0)

# %%
def can_be_ranked(df):
    rankable = {}
    for column in df.columns:
        if pd.api.types.is_numeric_dtype(df[column]):
            rankable[column] = True
        else:
            rankable[column] = False
    return rankable
rankable_columns = can_be_ranked(df)
rankable_columns
# Out:
# {'AveragScore': True,
#  'SafetySecurity': True,
#  'PersonelFreedom': True,
#  'Governance': True,
#  'InvestmentEnvironment': True,
#  'EnterpriseConditions': True,
#  'MarketAccessInfrastructure': True,
#  'EconomicQuality': True,
#  'LivingConditions': True,
#  'Health': True,
#  'Education': True}

# %%
# Example of the Mann-Whitney U Test
from scipy.stats import mannwhitneyu
df.dropna(inplace=True)
numeric_df = df.select_dtypes(include=['number'])

for col1 in numeric_df.columns:
    for col2 in numeric_df.columns:
        if col1 != col2:  
            data1 = numeric_df[col1]
            data2 = numeric_df[col2]
            stat, p = mannwhitneyu(data1, data2)
            if p > 0.05:
                print('Probably the same distribution')
# Out:
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution

# %%
# check if df_numeric can be paired
def can_be_paired(df):
    pairable = {}
    for column in df.columns:
        if pd.api.types.is_numeric_dtype(df[column]):
            pairable[column] = True
        else:
            pairable[column] = False
    return pairable
pairable_columns = can_be_paired(numeric_df)

# %%
pairable_columns
# Out:
# {'AveragScore': True,
#  'SafetySecurity': True,
#  'PersonelFreedom': True,
#  'Governance': True,
#  'InvestmentEnvironment': True,
#  'EnterpriseConditions': True,
#  'MarketAccessInfrastructure': True,
#  'EconomicQuality': True,
#  'LivingConditions': True,
#  'Health': True,
#  'Education': True}

# %%
# Example of the Wilcoxon Signed-Rank Test
from scipy.stats import wilcoxon

for col1 in pairable_columns:
    for col2 in pairable_columns:
        if col1 != col2:
            if pairable_columns[col1] and pairable_columns[col2]:
                data1 = numeric_df[col1]
                data2 = numeric_df[col2]
                stat, p = wilcoxon(data1, data2)
                if p > 0.05:
                    print('Probably the same distribution')
# Out:
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution

# %%
from scipy.stats import kruskal

for col1 in numeric_df.columns:
    for col2 in numeric_df.columns:
        if col1 != col2:
            data1 = numeric_df[col1]
            data2 = numeric_df[col2]
            stat, p = kruskal(data1, data2)
            if p > 0.05:
                print('Probably the same distribution')
# Out:
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution
# Probably the same distribution

# %%
import pandas as pd
from scipy.stats import friedmanchisquare
from sklearn.preprocessing import StandardScaler

# Assuming numeric_df is your dataframe containing numeric data
# Select numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Normalize the data
scaler = StandardScaler()
normalized_df = pd.DataFrame(scaler.fit_transform(numeric_df), columns=numeric_df.columns)

# Define pairable_columns as the list of column names to be tested
pairable_columns = normalized_df.columns

# Perform the Friedman test
for i, col1 in enumerate(pairable_columns):
    for j, col2 in enumerate(pairable_columns):
        for k, col3 in enumerate(pairable_columns):
            if i < j < k:  # Ensure unique triplets
                data1 = normalized_df[col1]
                data2 = normalized_df[col2]
                data3 = normalized_df[col3]
                stat, p = friedmanchisquare(data1, data2, data3)
                print(f'Statistics for {col1} vs {col2} vs {col3}: stat={stat:.3f}, p={p:.3f}')
                if p > 0.05:
                    print('Probably the same distribution')
                else:
                    print('Probably different distributions')
# Out:
# Statistics for AveragScore vs SafetySecurity vs PersonelFreedom: stat=3.641, p=0.162
# Probably the same distribution
# Statistics for AveragScore vs SafetySecurity vs Governance: stat=0.048, p=0.976
# Probably the same distribution
# Statistics for AveragScore vs SafetySecurity vs InvestmentEnvironment: stat=0.515, p=0.773
# Probably the same distribution
# Statistics for AveragScore vs SafetySecurity vs EnterpriseConditions: stat=0.084, p=0.959
# Probably the same distribution
# Statistics for AveragScore vs SafetySecurity vs MarketAccessInfrastructure: stat=1.593, p=0.451
# Probably the same distribution
# Statistics for AveragScore vs SafetySecurity vs EconomicQuality: stat=0.048, p=0.976
# Probably the same distribution
# Statistics for AveragScore vs SafetySecurity vs LivingConditions: stat=0.443, p=0.801
# Probably the same distribution
# Statistics for AveragScore vs SafetySecurity vs Health: stat=0.335, p=0.846
# Probably the same distribution
# Statistics for AveragScore vs SafetySecurity vs Education: stat=0.467, p=0.792
# Probably the same distribution
# Statistics for AveragScore vs PersonelFreedom vs Governance: stat=4.204, p=0.122
# Probably the same distribution
# Statistics for AveragScore vs PersonelFreedom vs InvestmentEnvironment: stat=6.120, p=0.047
# Probably different distributions
# Statistics for AveragScore vs PersonelFreedom vs EnterpriseConditions: stat=6.551, p=0.038
# Probably different distributions
# Statistics for AveragScore vs PersonelFreedom vs MarketAccessInfrastructure: stat=5.940, p=0.051
# Probably the same distribution
# Statistics for AveragScore vs PersonelFreedom vs EconomicQuality: stat=4.754, p=0.093
# Probably the same distribution
# Statistics for AveragScore vs PersonelFreedom vs LivingConditions: stat=4.395, p=0.111
# Probably the same distribution
# Statistics for AveragScore vs PersonelFreedom vs Health: stat=6.575, p=0.037
# Probably different distributions
# Statistics for AveragScore vs PersonelFreedom vs Education: stat=5.605, p=0.061
# Probably the same distribution
# Statistics for AveragScore vs Governance vs InvestmentEnvironment: stat=0.443, p=0.801
# Probably the same distribution
# Statistics for AveragScore vs Governance vs EnterpriseConditions: stat=0.156, p=0.925
# Probably the same distribution
# Statistics for AveragScore vs Governance vs MarketAccessInfrastructure: stat=0.431, p=0.806
# Probably the same distribution
# Statistics for AveragScore vs Governance vs EconomicQuality: stat=0.874, p=0.646
# Probably the same distribution
# Statistics for AveragScore vs Governance vs LivingConditions: stat=0.156, p=0.925
# Probably the same distribution
# Statistics for AveragScore vs Governance vs Health: stat=0.299, p=0.861
# Probably the same distribution
# Statistics for AveragScore vs Governance vs Education: stat=0.192, p=0.909
# Probably the same distribution
# Statistics for AveragScore vs InvestmentEnvironment vs EnterpriseConditions: stat=0.251, p=0.882
# Probably the same distribution
# Statistics for AveragScore vs InvestmentEnvironment vs MarketAccessInfrastructure: stat=2.168, p=0.338
# Probably the same distribution
# Statistics for AveragScore vs InvestmentEnvironment vs EconomicQuality: stat=0.575, p=0.750
# Probably the same distribution
# Statistics for AveragScore vs InvestmentEnvironment vs LivingConditions: stat=1.198, p=0.549
# Probably the same distribution
# Statistics for AveragScore vs InvestmentEnvironment vs Health: stat=0.251, p=0.882
# Probably the same distribution
# Statistics for AveragScore vs InvestmentEnvironment vs Education: stat=3.701, p=0.157
# Probably the same distribution
# Statistics for AveragScore vs EnterpriseConditions vs MarketAccessInfrastructure: stat=0.802, p=0.670
# Probably the same distribution
# Statistics for AveragScore vs EnterpriseConditions vs EconomicQuality: stat=0.108, p=0.948
# Probably the same distribution
# Statistics for AveragScore vs EnterpriseConditions vs LivingConditions: stat=0.228, p=0.892
# Probably the same distribution
# Statistics for AveragScore vs EnterpriseConditions vs Health: stat=0.443, p=0.801
# Probably the same distribution
# Statistics for AveragScore vs EnterpriseConditions vs Education: stat=1.090, p=0.580
# Probably the same distribution
# Statistics for AveragScore vs MarketAccessInfrastructure vs EconomicQuality: stat=1.198, p=0.549
# Probably the same distribution
# Statistics for AveragScore vs MarketAccessInfrastructure vs LivingConditions: stat=1.725, p=0.422
# Probably the same distribution
# Statistics for AveragScore vs MarketAccessInfrastructure vs Health: stat=0.371, p=0.831
# Probably the same distribution
# Statistics for AveragScore vs MarketAccessInfrastructure vs Education: stat=2.096, p=0.351
# Probably the same distribution
# Statistics for AveragScore vs EconomicQuality vs LivingConditions: stat=0.898, p=0.638
# Probably the same distribution
# Statistics for AveragScore vs EconomicQuality vs Health: stat=0.084, p=0.959
# Probably the same distribution
# Statistics for AveragScore vs EconomicQuality vs Education: stat=1.341, p=0.511
# Probably the same distribution
# Statistics for AveragScore vs LivingConditions vs Health: stat=0.515, p=0.773
# Probably the same distribution
# Statistics for AveragScore vs LivingConditions vs Education: stat=0.910, p=0.634
# Probably the same distribution
# Statistics for AveragScore vs Health vs Education: stat=0.443, p=0.801
# Probably the same distribution
# Statistics for SafetySecurity vs PersonelFreedom vs Governance: stat=2.407, p=0.300
# Probably the same distribution
# Statistics for SafetySecurity vs PersonelFreedom vs InvestmentEnvironment: stat=3.641, p=0.162
# Probably the same distribution
# Statistics for SafetySecurity vs PersonelFreedom vs EnterpriseConditions: stat=4.395, p=0.111
# Probably the same distribution
# Statistics for SafetySecurity vs PersonelFreedom vs MarketAccessInfrastructure: stat=3.749, p=0.153
# Probably the same distribution
# Statistics for SafetySecurity vs PersonelFreedom vs EconomicQuality: stat=2.958, p=0.228
# Probably the same distribution
# Statistics for SafetySecurity vs PersonelFreedom vs LivingConditions: stat=2.838, p=0.242
# Probably the same distribution
# Statistics for SafetySecurity vs PersonelFreedom vs Health: stat=5.545, p=0.063
# Probably the same distribution
# Statistics for SafetySecurity vs PersonelFreedom vs Education: stat=3.246, p=0.197
# Probably the same distribution
# Statistics for SafetySecurity vs Governance vs InvestmentEnvironment: stat=0.048, p=0.976
# Probably the same distribution
# Statistics for SafetySecurity vs Governance vs EnterpriseConditions: stat=0.036, p=0.982
# Probably the same distribution
# Statistics for SafetySecurity vs Governance vs MarketAccessInfrastructure: stat=0.467, p=0.792
# Probably the same distribution
# Statistics for SafetySecurity vs Governance vs EconomicQuality: stat=0.443, p=0.801
# Probably the same distribution
# Statistics for SafetySecurity vs Governance vs LivingConditions: stat=0.335, p=0.846
# Probably the same distribution
# Statistics for SafetySecurity vs Governance vs Health: stat=0.970, p=0.616
# Probably the same distribution
# Statistics for SafetySecurity vs Governance vs Education: stat=0.251, p=0.882
# Probably the same distribution
# Statistics for SafetySecurity vs InvestmentEnvironment vs EnterpriseConditions: stat=0.335, p=0.846
# Probably the same distribution
# Statistics for SafetySecurity vs InvestmentEnvironment vs MarketAccessInfrastructure: stat=0.443, p=0.801
# Probably the same distribution
# Statistics for SafetySecurity vs InvestmentEnvironment vs EconomicQuality: stat=0.108, p=0.948
# Probably the same distribution
# Statistics for SafetySecurity vs InvestmentEnvironment vs LivingConditions: stat=0.946, p=0.623
# Probably the same distribution
# Statistics for SafetySecurity vs InvestmentEnvironment vs Health: stat=0.623, p=0.732
# Probably the same distribution
# Statistics for SafetySecurity vs InvestmentEnvironment vs Education: stat=2.060, p=0.357
# Probably the same distribution
# Statistics for SafetySecurity vs EnterpriseConditions vs MarketAccessInfrastructure: stat=0.228, p=0.892
# Probably the same distribution
# Statistics for SafetySecurity vs EnterpriseConditions vs EconomicQuality: stat=0.084, p=0.959
# Probably the same distribution
# Statistics for SafetySecurity vs EnterpriseConditions vs LivingConditions: stat=0.228, p=0.892
# Probably the same distribution
# Statistics for SafetySecurity vs EnterpriseConditions vs Health: stat=1.305, p=0.521
# Probably the same distribution
# Statistics for SafetySecurity vs EnterpriseConditions vs Education: stat=0.323, p=0.851
# Probably the same distribution
# Statistics for SafetySecurity vs MarketAccessInfrastructure vs EconomicQuality: stat=0.371, p=0.831
# Probably the same distribution
# Statistics for SafetySecurity vs MarketAccessInfrastructure vs LivingConditions: stat=1.341, p=0.511
# Probably the same distribution
# Statistics for SafetySecurity vs MarketAccessInfrastructure vs Health: stat=1.952, p=0.377
# Probably the same distribution
# Statistics for SafetySecurity vs MarketAccessInfrastructure vs Education: stat=0.084, p=0.959
# Probably the same distribution
# Statistics for SafetySecurity vs EconomicQuality vs LivingConditions: stat=0.910, p=0.634
# Probably the same distribution
# Statistics for SafetySecurity vs EconomicQuality vs Health: stat=1.114, p=0.573
# Probably the same distribution
# Statistics for SafetySecurity vs EconomicQuality vs Education: stat=0.251, p=0.882
# Probably the same distribution
# Statistics for SafetySecurity vs LivingConditions vs Health: stat=2.347, p=0.309
# Probably the same distribution
# Statistics for SafetySecurity vs LivingConditions vs Education: stat=0.335, p=0.846
# Probably the same distribution
# Statistics for SafetySecurity vs Health vs Education: stat=0.371, p=0.831
# Probably the same distribution
# Statistics for PersonelFreedom vs Governance vs InvestmentEnvironment: stat=4.036, p=0.133
# Probably the same distribution
# Statistics for PersonelFreedom vs Governance vs EnterpriseConditions: stat=4.898, p=0.086
# Probably the same distribution
# Statistics for PersonelFreedom vs Governance vs MarketAccessInfrastructure: stat=3.605, p=0.165
# Probably the same distribution
# Statistics for PersonelFreedom vs Governance vs EconomicQuality: stat=3.916, p=0.141
# Probably the same distribution
# Statistics for PersonelFreedom vs Governance vs LivingConditions: stat=2.922, p=0.232
# Probably the same distribution
# Statistics for PersonelFreedom vs Governance vs Health: stat=5.114, p=0.078
# Probably the same distribution
# Statistics for PersonelFreedom vs Governance vs Education: stat=3.605, p=0.165
# Probably the same distribution
# Statistics for PersonelFreedom vs InvestmentEnvironment vs EnterpriseConditions: stat=7.054, p=0.029
# Probably different distributions
# Statistics for PersonelFreedom vs InvestmentEnvironment vs MarketAccessInfrastructure: stat=5.222, p=0.073
# Probably the same distribution
# Statistics for PersonelFreedom vs InvestmentEnvironment vs EconomicQuality: stat=4.778, p=0.092
# Probably the same distribution
# Statistics for PersonelFreedom vs InvestmentEnvironment vs LivingConditions: stat=4.647, p=0.098
# Probably the same distribution
# Statistics for PersonelFreedom vs InvestmentEnvironment vs Health: stat=6.623, p=0.036
# Probably different distributions
# Statistics for PersonelFreedom vs InvestmentEnvironment vs Education: stat=7.198, p=0.027
# Probably different distributions
# Statistics for PersonelFreedom vs EnterpriseConditions vs MarketAccessInfrastructure: stat=6.084, p=0.048
# Probably different distributions
# Statistics for PersonelFreedom vs EnterpriseConditions vs EconomicQuality: stat=5.617, p=0.060
# Probably the same distribution
# Statistics for PersonelFreedom vs EnterpriseConditions vs LivingConditions: stat=5.186, p=0.075
# Probably the same distribution
# Statistics for PersonelFreedom vs EnterpriseConditions vs Health: stat=7.916, p=0.019
# Probably different distributions
# Statistics for PersonelFreedom vs EnterpriseConditions vs Education: stat=6.180, p=0.046
# Probably different distributions
# Statistics for PersonelFreedom vs MarketAccessInfrastructure vs EconomicQuality: stat=4.395, p=0.111
# Probably the same distribution
# Statistics for PersonelFreedom vs MarketAccessInfrastructure vs LivingConditions: stat=4.635, p=0.099
# Probably the same distribution
# Statistics for PersonelFreedom vs MarketAccessInfrastructure vs Health: stat=7.042, p=0.030
# Probably different distributions
# Statistics for PersonelFreedom vs MarketAccessInfrastructure vs Education: stat=4.898, p=0.086
# Probably the same distribution
# Statistics for PersonelFreedom vs EconomicQuality vs LivingConditions: stat=4.024, p=0.134
# Probably the same distribution
# Statistics for PersonelFreedom vs EconomicQuality vs Health: stat=6.120, p=0.047
# Probably different distributions
# Statistics for PersonelFreedom vs EconomicQuality vs Education: stat=4.778, p=0.092
# Probably the same distribution
# Statistics for PersonelFreedom vs LivingConditions vs Health: stat=6.898, p=0.032
# Probably different distributions
# Statistics for PersonelFreedom vs LivingConditions vs Education: stat=3.988, p=0.136
# Probably the same distribution
# Statistics for PersonelFreedom vs Health vs Education: stat=6.084, p=0.048
# Probably different distributions
# Statistics for Governance vs InvestmentEnvironment vs EnterpriseConditions: stat=0.371, p=0.831
# Probably the same distribution
# Statistics for Governance vs InvestmentEnvironment vs MarketAccessInfrastructure: stat=0.048, p=0.976
# Probably the same distribution
# Statistics for Governance vs InvestmentEnvironment vs EconomicQuality: stat=0.802, p=0.670
# Probably the same distribution
# Statistics for Governance vs InvestmentEnvironment vs LivingConditions: stat=0.515, p=0.773
# Probably the same distribution
# Statistics for Governance vs InvestmentEnvironment vs Health: stat=0.156, p=0.925
# Probably the same distribution
# Statistics for Governance vs InvestmentEnvironment vs Education: stat=1.760, p=0.415
# Probably the same distribution
# Statistics for Governance vs EnterpriseConditions vs MarketAccessInfrastructure: stat=0.048, p=0.976
# Probably the same distribution
# Statistics for Governance vs EnterpriseConditions vs EconomicQuality: stat=0.683, p=0.711
# Probably the same distribution
# Statistics for Governance vs EnterpriseConditions vs LivingConditions: stat=0.036, p=0.982
# Probably the same distribution
# Statistics for Governance vs EnterpriseConditions vs Health: stat=0.587, p=0.746
# Probably the same distribution
# Statistics for Governance vs EnterpriseConditions vs Education: stat=0.144, p=0.931
# Probably the same distribution
# Statistics for Governance vs MarketAccessInfrastructure vs EconomicQuality: stat=0.251, p=0.882
# Probably the same distribution
# Statistics for Governance vs MarketAccessInfrastructure vs LivingConditions: stat=1.234, p=0.540
# Probably the same distribution
# Statistics for Governance vs MarketAccessInfrastructure vs Health: stat=1.198, p=0.549
# Probably the same distribution
# Statistics for Governance vs MarketAccessInfrastructure vs Education: stat=0.371, p=0.831
# Probably the same distribution
# Statistics for Governance vs EconomicQuality vs LivingConditions: stat=0.587, p=0.746
# Probably the same distribution
# Statistics for Governance vs EconomicQuality vs Health: stat=0.802, p=0.670
# Probably the same distribution
# Statistics for Governance vs EconomicQuality vs Education: stat=0.156, p=0.925
# Probably the same distribution
# Statistics for Governance vs LivingConditions vs Health: stat=1.401, p=0.496
# Probably the same distribution
# Statistics for Governance vs LivingConditions vs Education: stat=0.228, p=0.892
# Probably the same distribution
# Statistics for Governance vs Health vs Education: stat=0.048, p=0.976
# Probably the same distribution
# Statistics for InvestmentEnvironment vs EnterpriseConditions vs MarketAccessInfrastructure: stat=0.587, p=0.746
# Probably the same distribution
# Statistics for InvestmentEnvironment vs EnterpriseConditions vs EconomicQuality: stat=0.575, p=0.750
# Probably the same distribution
# Statistics for InvestmentEnvironment vs EnterpriseConditions vs LivingConditions: stat=1.341, p=0.511
# Probably the same distribution
# Statistics for InvestmentEnvironment vs EnterpriseConditions vs Health: stat=0.587, p=0.746
# Probably the same distribution
# Statistics for InvestmentEnvironment vs EnterpriseConditions vs Education: stat=4.108, p=0.128
# Probably the same distribution
# Statistics for InvestmentEnvironment vs MarketAccessInfrastructure vs EconomicQuality: stat=0.251, p=0.882
# Probably the same distribution
# Statistics for InvestmentEnvironment vs MarketAccessInfrastructure vs LivingConditions: stat=2.048, p=0.359
# Probably the same distribution
# Statistics for InvestmentEnvironment vs MarketAccessInfrastructure vs Health: stat=0.731, p=0.694
# Probably the same distribution
# Statistics for InvestmentEnvironment vs MarketAccessInfrastructure vs Education: stat=3.269, p=0.195
# Probably the same distribution
# Statistics for InvestmentEnvironment vs EconomicQuality vs LivingConditions: stat=1.593, p=0.451
# Probably the same distribution
# Statistics for InvestmentEnvironment vs EconomicQuality vs Health: stat=0.335, p=0.846
# Probably the same distribution
# Statistics for InvestmentEnvironment vs EconomicQuality vs Education: stat=3.749, p=0.153
# Probably the same distribution
# Statistics for InvestmentEnvironment vs LivingConditions vs Health: stat=1.162, p=0.559
# Probably the same distribution
# Statistics for InvestmentEnvironment vs LivingConditions vs Education: stat=3.605, p=0.165
# Probably the same distribution
# Statistics for InvestmentEnvironment vs Health vs Education: stat=2.527, p=0.283
# Probably the same distribution
# Statistics for EnterpriseConditions vs MarketAccessInfrastructure vs EconomicQuality: stat=0.048, p=0.976
# Probably the same distribution
# Statistics for EnterpriseConditions vs MarketAccessInfrastructure vs LivingConditions: stat=1.006, p=0.605
# Probably the same distribution
# Statistics for EnterpriseConditions vs MarketAccessInfrastructure vs Health: stat=1.521, p=0.467
# Probably the same distribution
# Statistics for EnterpriseConditions vs MarketAccessInfrastructure vs Education: stat=0.587, p=0.746
# Probably the same distribution
# Statistics for EnterpriseConditions vs EconomicQuality vs LivingConditions: stat=0.587, p=0.746
# Probably the same distribution
# Statistics for EnterpriseConditions vs EconomicQuality vs Health: stat=0.946, p=0.623
# Probably the same distribution
# Statistics for EnterpriseConditions vs EconomicQuality vs Education: stat=0.910, p=0.634
# Probably the same distribution
# Statistics for EnterpriseConditions vs LivingConditions vs Health: stat=2.024, p=0.363
# Probably the same distribution
# Statistics for EnterpriseConditions vs LivingConditions vs Education: stat=0.335, p=0.846
# Probably the same distribution
# Statistics for EnterpriseConditions vs Health vs Education: stat=0.898, p=0.638
# Probably the same distribution
# Statistics for MarketAccessInfrastructure vs EconomicQuality vs LivingConditions: stat=2.024, p=0.363
# Probably the same distribution
# Statistics for MarketAccessInfrastructure vs EconomicQuality vs Health: stat=1.293, p=0.524
# Probably the same distribution
# Statistics for MarketAccessInfrastructure vs EconomicQuality vs Education: stat=0.802, p=0.670
# Probably the same distribution
# Statistics for MarketAccessInfrastructure vs LivingConditions vs Health: stat=3.269, p=0.195
# Probably the same distribution
# Statistics for MarketAccessInfrastructure vs LivingConditions vs Education: stat=1.593, p=0.451
# Probably the same distribution
# Statistics for MarketAccessInfrastructure vs Health vs Education: stat=1.114, p=0.573
# Probably the same distribution
# Statistics for EconomicQuality vs LivingConditions vs Health: stat=1.952, p=0.377
# Probably the same distribution
# Statistics for EconomicQuality vs LivingConditions vs Education: stat=1.401, p=0.496
# Probably the same distribution
# Statistics for EconomicQuality vs Health vs Education: stat=0.910, p=0.634
# Probably the same distribution
# Statistics for LivingConditions vs Health vs Education: stat=0.802, p=0.670
# Probably the same distribution
